# %%
# !pip install ipython
# !pip install roboflow
# !pip install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.2.31-py3-none-any.whl (780 kB)
# ...
#   Using cached ultralytics_thop-0.2.8-py3-none-any.whl (25 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display

display.clear_output()
# !yolo mode=checks
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 532, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {MODES}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=<module 'ultralytics.utils.checks' from '/usr/local/lib/python3.10/dist-packages/ultralytics/utils/checks.py'>'. Valid modes are {'val', 'export', 'predict', 'train', 'track', 'benchmark'}.
#
#     Arguments received: ['yolo', 'mode=checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of {'segment', 'detect', 'obb', 'pose', 'classify'}
#                 MODE (required) is one of {'val', 'export', 'predict', 'train', 'track', 'benchmark'}
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="AWUx0q4LzWSt9eM7lk6Z")
project = rf.workspace("fynd").project("biscuit_detection-yctah")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.31, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to Biscuit_detection-1 in yolov8:: 100%|██████████| 158/158 [00:00<00:00, 3919.05it/s]

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/Biscuit_detection-1/data.yaml epochs=150 imgsz=640
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 189MB/s]
# Ultralytics YOLOv8.2.31 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/Biscuit_detection-1/data.yaml epochs=200 imgsz=640
# Out:
# Ultralytics YOLOv8.2.31 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !cp /content/runs/detect/train2/weights/best.pt /content/drive/MyDrive/weights/

# %%
# !cp /content/runs/detect/train2/weights/last.pt /content/drive/MyDrive/weights/

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/Biscuit_detection-1/data.yaml epochs=300 imgsz=640
# Out:
# Ultralytics YOLOv8.2.31 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !cp /content/runs/detect/train3/weights/best.pt /content/drive/MyDrive/weights/
# !cp /content/runs/detect/train3/weights/last.pt /content/drive/MyDrive/weights/

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train3/weights/best.pt source="/content/Capture-2024-06-11-220419.png"
# Out:
# Ultralytics YOLOv8.2.31 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006623 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/Capture-2024-06-11-220419.png: 416x640 1 Hide and Seek, 114.6ms
# Speed: 4.5ms preprocess, 114.6ms inference, 674.6ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
