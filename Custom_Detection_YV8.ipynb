# %%
# !pip install ipython
# !pip install roboflow
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.5/75.5 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 19.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.0 MB/s eta 0:00:00
# ...
# WARNING: The candidate selected for download or install is a yanked version: 'opencv-python-headless' candidate (version 4.8.0.74 at https://files.pythonhosted.org/packages/76/02/f128517f3ade4bb5f71e2afd8461dba70e3f466ce745fa1fd1fade9ad1b7/opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from https://pypi.org/simple/opencv-python-headless/) (requires-python:>=3.6))
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display

display.clear_output()
# !yolo mode=checks
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 524, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {MODES}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=<module 'ultralytics.utils.checks' from '/usr/local/lib/python3.10/dist-packages/ultralytics/utils/checks.py'>'. Valid modes are {'train', 'val', 'export', 'predict', 'benchmark', 'track'}.
#
#     Arguments received: ['yolo', 'mode=checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of {'detect', 'obb', 'classify', 'segment', 'pose'}
#                 MODE (required) is one of {'train', 'val', 'export', 'predict', 'benchmark', 'track'}
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="AWUx0q4LzWSt9eM7lk6Z")
project = rf.workspace("se-mpau8").project("se-hackthon")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.28, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to SE-hackthon-1 in yolov8:: 100%|██████████| 1357/1357 [00:00<00:00, 7511.08it/s]

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/SE-hackthon-1/data.yaml epochs=50 imgsz=640
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 69.1MB/s]
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename=f'/content/runs/detect/train/confusion_matrix.png', width=600)

# %%
Image(filename=f'/content/runs/detect/train2/confusion_matrix.png')

# %%
Image(filename=f'/content/runs/detect/train2/results.png', width=600)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/runs/detect/train2/weights/best.pt /content/drive/MyDrive

# %%
# !cp /content/runs/detect/train2/weights/last.pt /content/drive/MyDrive

# %%
# !cp /content/yolov8n.pt /content/drive/MyDrive

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train2/weights/best.pt data=/content/SE-hackthon-1/data.yaml
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3008573 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/SE-hackthon-1/valid/labels.cache... 53 images, 0 backgrounds, 0 corrupt: 100% 53/53 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:03<00:00,  1.09it/s]
#                    all         53         53      0.793      0.718      0.866      0.726
#         Anmol_Biscuits          2          2      0.507          1      0.995       0.92
#      Britannia_Bourbon          2          2      0.873          1      0.995      0.696
#     Britannia_Good_Day          1          1          1          0      0.995      0.796
#   Britannia_Mari_-Gold          4          4      0.744       0.75      0.735      0.681
#    Hide_-_Seek_-Parle-          4          4          1      0.787      0.995      0.772
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt source="/content/Screenshot 2024-06-03 at 1.14.11 PM.png"
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3008573 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/Screenshot 2024-06-03 at 1.14.11 PM.png: 640x640 1 McVitie-s_Digestive, 10.8ms
# Speed: 6.6ms preprocess, 10.8ms inference, 618.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt source="/content/Screenshot 2024-06-03 at 1.14.25 PM.png"
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3008573 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/Screenshot 2024-06-03 at 1.14.25 PM.png: 640x640 1 Hide_-_Seek_-Parle-, 10.3ms
# Speed: 6.0ms preprocess, 10.3ms inference, 557.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !cp /content/runs/detect/predict2/hideandseek.png /content/drive/MyDrive
